# %% [markdown]
# # Jupyter Notebooks + GitHub Pages Integration Guide
#
# ## For AEDES Colorado Disease Surveillance
#
# **Objective**: Compare integration options for publishing Jupyter Notebook analysis with GitHub Pages.
#
# **Your Use Case**: Publishing disease surveillance analysis, data dashboards, and forecasts for Colorado (Lyme, West Nile, Bird Flu).
#
# **Decision Matrix**: When to use each approach based on interactivity needs, automation, and complexity.
